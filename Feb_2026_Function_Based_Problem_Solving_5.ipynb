# %% [markdown]
# # **Task - 5 Function-Based Problem Solving**
# ## **Data Science Internship – February 2026**
# ## Task 5: Feb Internship Function-Based Problem Solving
# **Name: Kataram Navya Sree**
#
# **Date: 20-02-2026**

# %% [markdown]
# # **Problem 1: Social Media – Post Engagement Analyzer**
# ## **Problem Statement**
# ## Create a function to analyze engagement on a social media post.
# ## **Rules**
# * Calculate total likes
# * If Total Likes ≥ 1000 → Viral Post
# * Otherwise → Normal Engagement

# %%
# Function to analyze post engagement
def analyze_engagement(likes_list):

    total_likes = 0

    # loop to calculate total likes
    for like in likes_list:
        total_likes += like

    # condition to check viral or not
    if total_likes >= 1000:
        status = "Viral Post"
    else:
        status = "Normal Engagement"

    # print result
    print("Total Likes:", total_likes)
    print("Post Status:", status)


# ---- User Input ----
n = int(input("Enter number of posts: "))

likes = []
for i in range(n):
    value = int(input(f"Enter likes for post {i+1}: "))
    likes.append(value)

# call function
analyze_engagement(likes)
# Out:
# Enter number of posts: 2
# Enter likes for post 1: 500
# Enter likes for post 2: 550
# Total Likes: 1050
# Post Status: Viral Post

# %% [markdown]
# # **Problem 2: Healthcare – Medicine Stock Alert System**
# ## **Problem Statement**
# ## Create a function to monitor medicine stock levels.
# ## **Rules**
# * Stock < 10 → Low Stock Alert
# * Stock ≥ 10 → Stock Sufficient

# %%
# Function to check medicine stock
def check_stock(stock):

    if stock < 10:
        status = "Low Stock Alert"
    else:
        status = "Stock Sufficient"

    print("Medicine Stock:", stock)
    print("Status:", status)


# ---- User Input ----
stock_value = int(input("Enter medicine stock quantity: "))

# Call function
check_stock(stock_value)
# Out:
# Enter medicine stock quantity: 6
# Medicine Stock: 6
# Status: Low Stock Alert

# %% [markdown]
# # **Problem 3: Agriculture – Rainfall Adequacy Checker**
# ## **Problem Statement**
# ## Create a function that analyzes seasonal rainfall data.
# ## **Rules**
# * Calculate average rainfall
# * Average ≥ required level → Adequate Rainfall
# * Otherwise → Inadequate Rainfall

# %%
# Function to check rainfall adequacy
def check_rainfall(rainfall_list, required_level):

    total = 0
    for rain in rainfall_list:
        total += rain

    average = round(total / len(rainfall_list))

    if average >= required_level:
        status = "Adequate Rainfall"
    else:
        status = "Inadequate Rainfall"

    print("Average Rainfall:", average)
    print("Rainfall Status:", status)


# ---- Single Line Input ----
data = list(map(float, input().split()))

days = int(data[0])
rainfall_data = data[1:days+1]
required = data[-1]

check_rainfall(rainfall_data, required)
# Out:
# 4 60 70 80 78 70
# Average Rainfall: 72
# Rainfall Status: Adequate Rainfall

# %% [markdown]
# # **Problem 4: Social Media – Duplicate Account Detection**
# ## **Problem Statement**
# ## Create a function to detect duplicate usernames in a system.
# ## **Rules**
# * If duplicates exist → Flag accounts
# * Else → Accounts are unique

# %%
# Function to detect duplicate accounts
def check_duplicates(usernames):

    unique_users = set(usernames)

    if len(unique_users) < len(usernames):
        result = "Yes"
    else:
        result = "No"

    print("Duplicate Accounts Found:", result)


# ---- Single Line Input ----
data = input().split()

n = int(data[0])
users = data[1:n+1]

check_duplicates(users)
# Out:
# 5 john anna mike john sara
# Duplicate Accounts Found: Yes

# %% [markdown]
# # **Problem 5: Healthcare – Appointment Eligibility Checker**
# ## **Problem Statement**
# ## Create a function to check whether a patient is eligible for an appointment slot.
# ## **Rules**
# * Age ≥ 18 → Eligible
# * Age < 18 → Not Eligible

# %%
# Function to check appointment eligibility
def check_eligibility(age):

    if age >= 18:
        status = "Eligible"
    else:
        status = "Not Eligible"

    print("Patient Age:", age)
    print("Eligibility Status:", status)


# ---- One Line Input ----
age = int(input())

check_eligibility(age)
# Out:
# 21
# Patient Age: 21
# Eligibility Status: Eligible

# %% [markdown]
# # **Problem 6: Agriculture – Premium Crop Price Filter**
# ## **Problem Statement**
# ## Create a function that filters crop prices above a premium threshold.
# ## **Rules**
# * Price > ₹2000 → Premium Crop
# * Else → Regular Crop

# %%
# Function to filter premium crops
def filter_premium(prices):

    premium = []

    for price in prices:
        if price >= 2000:
            premium.append(price)

    print("Premium Crops:", premium)


# ---- Single Line Input ----
data = list(map(int, input().split()))

n = data[0]
prices = data[1:n+1]

filter_premium(prices)
# Out:
# 5 1500 2500 1800 3200 900
# Premium Crops: [2500, 3200]

# %% [markdown]
# # **Problem 7: System Monitoring – Application Health Checker**
# ## **Problem Statement**
# ## Create a function to evaluate application health based on error count.
# ## **Rules**
# * Errors = 0 → Healthy
# * Errors ≤ 5 → Minor Issues
# * Errors > 5 → Critical Issues

# %%
# Function to evaluate system health
def check_health(errors):

    if errors == 0:
        status = "Healthy"
    elif errors <= 5:
        status = "Minor Issues"
    else:
        status = "Critical Issues"

    print("Error Count:", errors)
    print("System Status:", status)


# ---- One Line Input ----
errors = int(input())

check_health(errors)
# Out:
# 7
# Error Count: 7
# System Status: Critical Issues

# %% [markdown]
# # **Problem 8: Banking – Daily Transaction Limit Checker**
# ## **Problem Statement**
# ## Create a function to validate daily transaction amount.
# ## **Rules**
# * Daily limit = ₹50,000
# * Amount within limit → Approved
# * Amount exceeds limit → Rejected

# %%
# Function to validate transaction
def check_transaction(amount):

    limit = 50000

    if amount <= limit:
        status = "Approved"
    else:
        status = "Rejected"

    print("Transaction Amount:", amount)
    print("Transaction Status:", status)


# ---- One Line Input ----
amount = int(input())

check_transaction(amount)
# Out:
# 60000
# Transaction Amount: 60000
# Transaction Status: Rejected

# %% [markdown]
# # **Problem 9: E-Learning – Student Attendance Eligibility System**
# ## **Problem Statement**
# ## Create a function to calculate attendance percentage and check exam eligibility.
# ## **Rules**
# * Attendance ≥ 75% → Eligible
# * Attendance < 75% → Not Eligible

# %%
# Function to calculate attendance eligibility
def check_attendance(total, attended):

    percentage = (attended / total) * 100

    if percentage >= 75:
        status = "Eligible"
    else:
        status = "Not Eligible"

    print("Attendance Percentage:", round(percentage, 1))
    print("Exam Eligibility:", status)


# ---- One Line Input ----
total, attended = map(int, input().split())

check_attendance(total, attended)
# Out:
# 50 40
# Attendance Percentage: 80.0
# Exam Eligibility: Eligible

# %% [markdown]
# # **Problem 10: Smart Electricity Bill Analyzer**
# ## **Problem Statement**
# ## You are building a smart electricity billing system for residential users. Create a function that calculates the electricity bill and classifies usage level based on units consumed.
# ## **Billing Rules**
# * First 100 units → ₹3 per unit
# * Next 100 units (101–200) → ₹5 per unit
# * Above 200 units → ₹7 per unit

# %%
# Function to calculate electricity bill
def calculate_bill(units):

    bill = 0

    if units <= 100:
        bill = units * 3

    elif units <= 200:
        bill = (100 * 3) + ((units - 100) * 5)

    else:
        bill = (100 * 3) + (100 * 5) + ((units - 200) * 7)

    # Usage classification
    if bill < 500:
        status = "Low Usage"
    elif bill <= 1500:
        status = "Moderate Usage"
    else:
        status = "High Usage"

    return bill, status


# ---- One Line Input ----
units = int(input())

bill, status = calculate_bill(units)

print("Electricity Bill:", bill)
print("Usage Status:", status)
# Out:
# 250
# Electricity Bill: 1150
# Usage Status: Moderate Usage
